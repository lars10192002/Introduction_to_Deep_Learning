# %%
import matplotlib.pyplot as plt

# %%
https://morvanzhou.github.io/tutorials/data-manipulation/plt/4-1-subpot1/

# %%
plt.figure()

plt.subplot(2,2,1)# 兩行兩列第一張圖
plt.plot([0,1],[0,1])
plt.subplot(2,2,2)
plt.plot([0,1],[0,3])

plt.show()

# %%
plt.figure()

plt.subplot(211)# 兩行兩列第一張圖
plt.plot([0,1],[0,1])
plt.subplot(234)
plt.plot([0,1],[0,2])
plt.subplot(235)
plt.plot([0,1],[0,3])
plt.subplot(236)
plt.plot([0,1],[0,4])
plt.show()

# %%
#https://zhuanlan.zhihu.com/p/24464836

# %%
distplot


displot()集合了matplotlib的hist()与核函数估计kdeplot的功能，增加了rugplot分布观测条显示与利用scipy库fit拟合参数分布的新颖用途。具体用法如下：



seaborn.distplot(a, bins=None, hist=True, kde=True, rug=False, fit=None, hist_kws=None, kde_kws=None, rug_kws=None, fit_kws=None, color=None, vertical=False, norm_hist=False, axlabel=None, label=None, ax=None)
先介绍一下直方图(Histograms)：

直方图又称质量分布图，它是表示资料变化情况的一种主要工具。用直方图可以解析出资料的规则性，比较直观地看出产品质量特性的分布状态，对于资料分布状况一目了然，便于判断其总体质量分布情况。直方图表示通过沿数据范围形成分箱，然后绘制条以显示落入每个分箱的观测次数的数据分布。

# %%
import seaborn as sns
import numpy as np

# %%
sns.set(color_codes=True)#导入seaborn包设定颜色

np.random.seed(sum(map(ord, "distributions")))

x = np.random.normal(size=100)
sns.distplot(x, kde=False, rug=True)
#kde=False关闭核密度分布,rug表示在x轴上每个观测上生成的小细条（边际毛毯）

# %%
sns.distplot(x, bins=20, kde=False, rug=True);#设置了20个矩形条

# %%
sns.distplot(x, hist=False, rug=True, fit=norm);#关闭直方图，开启rug细条
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-26000e205805> in <module>
# ----> 1 sns.distplot(x, hist=False, rug=True, fit=norm);#关闭直方图，开启rug细条
#
# NameError: name 'norm' is not defined

# %%
#scipy
#norm : https://blog.csdn.net/u011702002/article/details/78245804
#https://docs.scipy.org/doc/scipy-0.19.0/reference/generated/scipy.stats.norm.html
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-a5321775728d> in <module>
# ----> 1 sns.distplot(x,hist=False,fit=norm) #拟合标准正态分布
#
# NameError: name 'norm' is not defined

# %%
from scipy.stats import *

sns.distplot(x,hist=False,fit=norm) #拟合标准正态分布
